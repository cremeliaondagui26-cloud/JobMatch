# %% [markdown]
# # Data Analysis
# Objectif: analyser les distributions, correlations et tendances utiles au matching.

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.Series(dtype='float64').describe()
